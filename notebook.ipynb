# %% [markdown]
# You just got hired as the first and only data practitioner at a small business experiencing exponential growth. The company needs more structured processes, guidelines, and standards. Your first mission is to structure the human resources data. The data is currently scattered across teams and files and comes in various formats: Excel files, CSVs, JSON files...
#
# You'll work with the following data in the `datasets` folder:
# - __Office addresses__
#     - Saved in `office_addresses.csv`.
#     - If the value for office is `NaN`, then the employee is remote.
# - __Employee addresses__
#     - Saved on the first tab of `employee_information.xlsx`.
# - __Employee emergency contacts__
#     - Saved on the second tab of `employee_information.xlsx`; this tab is called `emergency_contacts`.
#     - However, this sheet was edited at some point, and ***the headers were removed***! The HR manager let you know that they should be: `employee_id`, `last_name`, `first_name`, `emergency_contact`, `emergency_contact_number`, and `relationship`.
# - __Employee roles, teams, and salaries__
#     - This information has been exported from the company's human resources management system into a JSON file titled `employee_roles.json`. Here are the first few lines of that file:
# ```
# {"A2R5H9":
#   {
#     "title": "CEO",
#     "monthly_salary": "$4500",
#     "team": "Leadership"
#   },
#  ...
# }
# ```

# %%
import pandas as pd
import json
Office_addr = pd.read_csv("office_addresses.csv")
print(Office_addr.head())
Employee_addr = pd.read_excel("employee_information.xlsx", "employee_addresses")
Employee_emrg = pd.read_excel("employee_information.xlsx", "emergency_contacts", names = ["employee_id", "last_name", "first_name", "emergency_contact", "emergency_contact_number","relationship"])

# Opening JSON file
with open("employee_roles.json") as json_file:
    Employee_info = json.load(json_file)

# Converting the json to dataframe
    
Employee_info_df = pd.DataFrame.from_dict(Employee_info, orient="index").reset_index()
Employee_info_df = Employee_info_df.rename(columns={'index':'employee_id' })

# Merging data frames
Employee_addr_emrg = Employee_addr.merge(Employee_emrg, on = "employee_id",  how = "outer").reset_index()
Employee_addr_emrg = Employee_addr_emrg.drop(['last_name', 'first_name'], axis = 1).reset_index()


# Merging Employee_ addr_emrg to office info on county
Employee_addr_emrg_office = Employee_addr_emrg.merge(Office_addr, left_on = "employee_country", right_on = "office_country",  how = "outer")#.reset_index()

# Merging Employee_addr_emrg_office  to json file data
employees_final = Employee_addr_emrg_office.merge(Employee_info_df, on = 'employee_id', how = "outer")#.reset_index()

# Converting NAN values in office column to "Remote"
employees_final[employees_final["office"].isnull() == True] = "Remote"

# Set employee_id as index

print(employees_final.head())
employees_final.reset_index()
employees_final.set_index("employee_id", inplace=True)
# Out:
#           office office_country    office_city   office_street  \
# 0  Leuven Office             BE         Leuven  Martelarenlaan
# 1     ESB Office             US  New York City    Fifth Avenue
# 2  WeWork Office             GB         London      Old Street
#
#    office_street_number
# 0                    38
# 1                   350
# 2                   207
#   level_0   index employee_id employee_last_name employee_first_name  \
# 0       0       0      A2R5H9             Hunman                 Jax
# 1       1       1      G4R7V0              Sagal               Gemma
# 2       2       2      H8K0L6               Siff                Tara
# 3  Remote  Remote      Remote             Remote              Remote
#
#   employee_country employee_city employee_street employee_street_number  \
# 0               BE        Leuven     Grote Markt                      9
# 1               US      New-York    Perry Street                     66
# 2               GB        London    Baker Street                    221
# 3           Remote        Remote          Remote                 Remote
#
#   emergency_contact emergency_contact_number relationship         office  \
# 0               NaN                      NaN          NaN  Leuven Office
# 1      John Newmark           +1-202-555-194      Husband     ESB Office
# 2   Wendy de Matteo         +44-020-5554-333       Sister  WeWork Office
# 3            Remote                   Remote       Remote         Remote
#
#   office_country    office_city   office_street office_street_number  \
# 0             BE         Leuven  Martelarenlaan                 38.0
# 1             US  New York City    Fifth Avenue                350.0
# 2             GB         London      Old Street                207.0
# 3         Remote         Remote          Remote               Remote
#
#                 title monthly_salary        team
# 0                 CEO          $4500  Leadership
# 1  Business Developer          $3000       Sales
# 2                 CFO          $4500  Leadership
# 3              Remote         Remote      Remote
# C:\Users\CSStaff-MS02\AppData\Local\Temp\ipykernel_25228\1513115373.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Remote' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   employees_final[employees_final["office"].isnull() == True] = "Remote"
# C:\Users\CSStaff-MS02\AppData\Local\Temp\ipykernel_25228\1513115373.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Remote' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   employees_final[employees_final["office"].isnull() == True] = "Remote"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25228\1513115373.py in ?()
#      30
#      31 # Set employee_id as index
#      32
#      33 print(employees_final.head())
# ---> 34 employees_final.reset_index()
#      35 employees_final.set_index("employee_id", inplace=True)
#      36
#      37 print("Next\n")
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6452                     level_values = algorithms.take(
#    6453                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6454                     )
#    6455
# -> 6456                 new_obj.insert(
#    6457                     0,
#    6458                     name,
#    6459                     level_values,
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5141                 "'self.flags.allows_duplicate_labels' is False."
#    5142             )
#    5143         if not allow_duplicates and column in self.columns:
#    5144             # Should this be a different kind of error??
# -> 5145             raise ValueError(f"cannot insert {column}, already exists")
#    5146         if not is_integer(loc):
#    5147             raise TypeError("loc must be int")
#    5148         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
print("employee info =")
print(Employee_info.keys())
# Out:
# office address =
# Index(['office', 'office_country', 'office_city', 'office_street',
#        'office_street_number'],
#       dtype='object')
# employee address =
# Index(['employee_id', 'employee_last_name', 'employee_first_name',
#        'employee_country', 'employee_city', 'employee_street',
#        'employee_street_number', 'emergency_contact',
#        'emergency_contact_number', 'relationship'],
#       dtype='object')
# employee info =
# Index(['A2R5H9', 'H8K0L6', 'G4R7V0', 'M1Z7U9'], dtype='object')

# %%
print(type(Employee_info))
# Merging Employee_addr_emrg_office  to json file data


print(Json_data2.head())
# Out:
# <class 'dict'>
#     index               title monthly_salary               team
# 0  A2R5H9                 CEO          $4500         Leadership
# 1  H8K0L6                 CFO          $4500         Leadership
# 2  G4R7V0  Business Developer          $3000              Sales
# 3  M1Z7U9      Office Manager          $2000  People Operations
#   employee_id               title monthly_salary               team
# 0      A2R5H9                 CEO          $4500         Leadership
# 1      H8K0L6                 CFO          $4500         Leadership
# 2      G4R7V0  Business Developer          $3000              Sales
# 3      M1Z7U9      Office Manager          $2000  People Operations
